# %%
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
import numpy as np

# %%
image = imread("/home/simon_g/src/CellPatchExtraction/data/IMC_42CHANNEL.tif")[:1000, :1000]
print(image.shape)
if image.shape[2] == 3:
    plt.imshow(image)
else:
    plt.imshow(image[..., 38])
# Out:
# (696, 696, 44)

# %%
from CellPatchExtraction.src.extraction import extract_patches
from cellpose.models import CellposeModel
from plotutils.patches import gridPlot

patches = extract_patches(image, "CP_TU", cellpose_kwargs={"diameter": 15, "min_size": 400}, patch_size=32, nuclear_channel=38)

# %%
gridPlot(patches, channels_to_show=[42, 43 , 38])
