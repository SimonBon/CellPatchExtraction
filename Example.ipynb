# %%
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
import numpy as np

# %%
image = imread("/data/IF_RGB.TIFF")[:500, :500]
print(image.shape)
if image.shape[2] == 3:
    plt.imshow(image)
else:
    plt.imshow(image[..., 38])
# Out:
# (500, 500, 3)

# %%
from CellPatchExtraction.src.extraction import extract_patches
from cellpose.models import CellposeModel
from plotutils.patches import gridPlot

patches = extract_patches(image, "CP_TU", cellpose_kwargs={"diameter": 15, "min_size": 400}, patch_size=32, nuclear_channel=3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/simon_g/src/CellPatchExtraction/Example.ipynb Cell 3 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Bccri/home/simon_g/src/CellPatchExtraction/Example.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from cellpose.models import CellposeModel
#       <a href='vscode-notebook-cell://ssh-remote%2Bccri/home/simon_g/src/CellPatchExtraction/Example.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> from plotutils.patches import gridPlot
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bccri/home/simon_g/src/CellPatchExtraction/Example.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> patches = extract_patches(image, "CP_TU", cellpose_kwargs={"diameter": 15, "min_size": 400}, patch_size=32, nuclear_channel=3)
#
# ...

# %%
gridPlot(patches, channels_to_show=[42, 43 , 38])
